// %% [markdown]
// # Multiples of 3 or 5
// I thought of using simple conditions: if the number is divisible by 3 or the number is divisible by 5 I would add it to the sum. So for 100 number it would take 100 steps. Therefor it would be O(n) for this solution

// %%
fun multipleSum(max: Int): Int {
    var sum = 0
    for (i in 3..<max)
        if (i % 3 == 0 || i % 5 == 0)
        sum += i
    return sum
}

// %%
multipleSum(1000)
// Out:
// 233168

// %% [markdown]
// Can I make it a little faster? I think if we are only finding multiples of 3 or 5 we could just multiply 3 and 5 until we get to the max number ?

// %%
fun multipleSum2(max: Int): Int {
    var sum = 0
    var mul5 = 5
    var mul3 = 3
    var i = 1
    while((mul5 * i) < max) {
        mul5 *= i
        println("Adding number: $mul5 to sum, multiplier: $i")
        sum += mul5
        mul5 /= i
        i++
    }
    i = 1
    while((mul3 * i) < max) {
        mul3 *= i
        if (i % 5 != 0) {
            sum += mul3
            println("Adding number: $mul3 to sum, multiplier: $i")
        }
        mul3 /= i
        i++
    }
    return sum
}

// %%
multipleSum2(1000)
// Out:
// Adding number: 5 to sum, multiplier: 1
// Adding number: 10 to sum, multiplier: 2
// Adding number: 15 to sum, multiplier: 3
// Adding number: 20 to sum, multiplier: 4
// Adding number: 25 to sum, multiplier: 5
// Adding number: 30 to sum, multiplier: 6
// Adding number: 35 to sum, multiplier: 7
// Adding number: 40 to sum, multiplier: 8
// Adding number: 45 to sum, multiplier: 9
// Adding number: 50 to sum, multiplier: 10
// Adding number: 55 to sum, multiplier: 11
// Adding number: 60 to sum, multiplier: 12
// Adding number: 65 to sum, multiplier: 13
// Adding number: 70 to sum, multiplier: 14
// Adding number: 75 to sum, multiplier: 15
// Adding number: 80 to sum, multiplier: 16
// Adding number: 85 to sum, multiplier: 17
// Adding number: 90 to sum, multiplier: 18
// Adding number: 95 to sum, multiplier: 19
// Adding number: 100 to sum, multiplier: 20
// Adding number: 105 to sum, multiplier: 21
// Adding number: 110 to sum, multiplier: 22
// Adding number: 115 to sum, multiplier: 23
// Adding number: 120 to sum, multiplier: 24
// Adding number: 125 to sum, multiplier: 25
// Adding number: 130 to sum, multiplier: 26
// Adding number: 135 to sum, multiplier: 27
// Adding number: 140 to sum, multiplier: 28
// Adding number: 145 to sum, multiplier: 29
// Adding number: 150 to sum, multiplier: 30
// Adding number: 155 to sum, multiplier: 31
// Adding number: 160 to sum, multiplier: 32
// Adding number: 165 to sum, multiplier: 33
// Adding number: 170 to sum, multiplier: 34
// Adding number: 175 to sum, multiplier: 35
// Adding number: 180 to sum, multiplier: 36
// Adding number: 185 to sum, multiplier: 37
// Adding number: 190 to sum, multiplier: 38
// Adding number: 195 to sum, multiplier: 39
// Adding number: 200 to sum, multiplier: 40
// Adding number: 205 to sum, multiplier: 41
// Adding number: 210 to sum, multiplier: 42
// Adding number: 215 to sum, multiplier: 43
// Adding number: 220 to sum, multiplier: 44
// Adding number: 225 to sum, multiplier: 45
// Adding number: 230 to sum, multiplier: 46
// Adding number: 235 to sum, multiplier: 47
// Adding number: 240 to sum, multiplier: 48
// Adding number: 245 to sum, multiplier: 49
// Adding number: 250 to sum, multiplier: 50
// Adding number: 255 to sum, multiplier: 51
// Adding number: 260 to sum, multiplier: 52
// Adding number: 265 to sum, multiplier: 53
// Adding number: 270 to sum, multiplier: 54
// Adding number: 275 to sum, multiplier: 55
// Adding number: 280 to sum, multiplier: 56
// Adding number: 285 to sum, multiplier: 57
// Adding number: 290 to sum, multiplier: 58
// Adding number: 295 to sum, multiplier: 59
// Adding number: 300 to sum, multiplier: 60
// Adding number: 305 to sum, multiplier: 61
// Adding number: 310 to sum, multiplier: 62
// Adding number: 315 to sum, multiplier: 63
// Adding number: 320 to sum, multiplier: 64
// Adding number: 325 to sum, multiplier: 65
// Adding number: 330 to sum, multiplier: 66
// Adding number: 335 to sum, multiplier: 67
// Adding number: 340 to sum, multiplier: 68
// Adding number: 345 to sum, multiplier: 69
// Adding number: 350 to sum, multiplier: 70
// Adding number: 355 to sum, multiplier: 71
// Adding number: 360 to sum, multiplier: 72
// Adding number: 365 to sum, multiplier: 73
// Adding number: 370 to sum, multiplier: 74
// Adding number: 375 to sum, multiplier: 75
// Adding number: 380 to sum, multiplier: 76
// Adding number: 385 to sum, multiplier: 77
// Adding number: 390 to sum, multiplier: 78
// Adding number: 395 to sum, multiplier: 79
// Adding number: 400 to sum, multiplier: 80
// Adding number: 405 to sum, multiplier: 81
// Adding number: 410 to sum, multiplier: 82
// Adding number: 415 to sum, multiplier: 83
// Adding number: 420 to sum, multiplier: 84
// Adding number: 425 to sum, multiplier: 85
// Adding number: 430 to sum, multiplier: 86
// Adding number: 435 to sum, multiplier: 87
// Adding number: 440 to sum, multiplier: 88
// Adding number: 445 to sum, multiplier: 89
// Adding number: 450 to sum, multiplier: 90
// Adding number: 455 to sum, multiplier: 91
// Adding number: 460 to sum, multiplier: 92
// Adding number: 465 to sum, multiplier: 93
// Adding number: 470 to sum, multiplier: 94
// Adding number: 475 to sum, multiplier: 95
// Adding number: 480 to sum, multiplier: 96
// Adding number: 485 to sum, multiplier: 97
// Adding number: 490 to sum, multiplier: 98
// Adding number: 495 to sum, multiplier: 99
// Adding number: 500 to sum, multiplier: 100
// Adding number: 505 to sum, multiplier: 101
// Adding number: 510 to sum, multiplier: 102
// Adding number: 515 to sum, multiplier: 103
// Adding number: 520 to sum, multiplier: 104
// Adding number: 525 to sum, multiplier: 105
// Adding number: 530 to sum, multiplier: 106
// Adding number: 535 to sum, multiplier: 107
// Adding number: 540 to sum, multiplier: 108
// Adding number: 545 to sum, multiplier: 109
// Adding number: 550 to sum, multiplier: 110
// Adding number: 555 to sum, multiplier: 111
// Adding number: 560 to sum, multiplier: 112
// Adding number: 565 to sum, multiplier: 113
// Adding number: 570 to sum, multiplier: 114
// Adding number: 575 to sum, multiplier: 115
// Adding number: 580 to sum, multiplier: 116
// Adding number: 585 to sum, multiplier: 117
// Adding number: 590 to sum, multiplier: 118
// Adding number: 595 to sum, multiplier: 119
// Adding number: 600 to sum, multiplier: 120
// Adding number: 605 to sum, multiplier: 121
// Adding number: 610 to sum, multiplier: 122
// Adding number: 615 to sum, multiplier: 123
// Adding number: 620 to sum, multiplier: 124
// Adding number: 625 to sum, multiplier: 125
// Adding number: 630 to sum, multiplier: 126
// Adding number: 635 to sum, multiplier: 127
// Adding number: 640 to sum, multiplier: 128
// Adding number: 645 to sum, multiplier: 129
// Adding number: 650 to sum, multiplier: 130
// Adding number: 655 to sum, multiplier: 131
// Adding number: 660 to sum, multiplier: 132
// Adding number: 665 to sum, multiplier: 133
// Adding number: 670 to sum, multiplier: 134
// Adding number: 675 to sum, multiplier: 135
// Adding number: 680 to sum, multiplier: 136
// Adding number: 685 to sum, multiplier: 137
// Adding number: 690 to sum, multiplier: 138
// Adding number: 695 to sum, multiplier: 139
// Adding number: 700 to sum, multiplier: 140
// Adding number: 705 to sum, multiplier: 141
// Adding number: 710 to sum, multiplier: 142
// Adding number: 715 to sum, multiplier: 143
// Adding number: 720 to sum, multiplier: 144
// Adding number: 725 to sum, multiplier: 145
// Adding number: 730 to sum, multiplier: 146
// Adding number: 735 to sum, multiplier: 147
// Adding number: 740 to sum, multiplier: 148
// Adding number: 745 to sum, multiplier: 149
// Adding number: 750 to sum, multiplier: 150
// Adding number: 755 to sum, multiplier: 151
// Adding number: 760 to sum, multiplier: 152
// Adding number: 765 to sum, multiplier: 153
// Adding number: 770 to sum, multiplier: 154
// Adding number: 775 to sum, multiplier: 155
// Adding number: 780 to sum, multiplier: 156
// Adding number: 785 to sum, multiplier: 157
// Adding number: 790 to sum, multiplier: 158
// Adding number: 795 to sum, multiplier: 159
// Adding number: 800 to sum, multiplier: 160
// Adding number: 805 to sum, multiplier: 161
// Adding number: 810 to sum, multiplier: 162
// Adding number: 815 to sum, multiplier: 163
// Adding number: 820 to sum, multiplier: 164
// Adding number: 825 to sum, multiplier: 165
// Adding number: 830 to sum, multiplier: 166
// Adding number: 835 to sum, multiplier: 167
// Adding number: 840 to sum, multiplier: 168
// Adding number: 845 to sum, multiplier: 169
// Adding number: 850 to sum, multiplier: 170
// Adding number: 855 to sum, multiplier: 171
// Adding number: 860 to sum, multiplier: 172
// Adding number: 865 to sum, multiplier: 173
// Adding number: 870 to sum, multiplier: 174
// Adding number: 875 to sum, multiplier: 175
// Adding number: 880 to sum, multiplier: 176
// Adding number: 885 to sum, multiplier: 177
// Adding number: 890 to sum, multiplier: 178
// Adding number: 895 to sum, multiplier: 179
// Adding number: 900 to sum, multiplier: 180
// Adding number: 905 to sum, multiplier: 181
// Adding number: 910 to sum, multiplier: 182
// Adding number: 915 to sum, multiplier: 183
// Adding number: 920 to sum, multiplier: 184
// Adding number: 925 to sum, multiplier: 185
// Adding number: 930 to sum, multiplier: 186
// Adding number: 935 to sum, multiplier: 187
// Adding number: 940 to sum, multiplier: 188
// Adding number: 945 to sum, multiplier: 189
// Adding number: 950 to sum, multiplier: 190
// Adding number: 955 to sum, multiplier: 191
// Adding number: 960 to sum, multiplier: 192
// Adding number: 965 to sum, multiplier: 193
// Adding number: 970 to sum, multiplier: 194
// Adding number: 975 to sum, multiplier: 195
// Adding number: 980 to sum, multiplier: 196
// Adding number: 985 to sum, multiplier: 197
// Adding number: 990 to sum, multiplier: 198
// Adding number: 995 to sum, multiplier: 199
// Adding number: 3 to sum, multiplier: 1
// Adding number: 6 to sum, multiplier: 2
// Adding number: 9 to sum, multiplier: 3
// Adding number: 12 to sum, multiplier: 4
// Adding number: 18 to sum, multiplier: 6
// Adding number: 21 to sum, multiplier: 7
// Adding number: 24 to sum, multiplier: 8
// Adding number: 27 to sum, multiplier: 9
// Adding number: 33 to sum, multiplier: 11
// Adding number: 36 to sum, multiplier: 12
// Adding number: 39 to sum, multiplier: 13
// Adding number: 42 to sum, multiplier: 14
// Adding number: 48 to sum, multiplier: 16
// Adding number: 51 to sum, multiplier: 17
// Adding number: 54 to sum, multiplier: 18
// Adding number: 57 to sum, multiplier: 19
// Adding number: 63 to sum, multiplier: 21
// Adding number: 66 to sum, multiplier: 22
// Adding number: 69 to sum, multiplier: 23
// Adding number: 72 to sum, multiplier: 24
// Adding number: 78 to sum, multiplier: 26
// Adding number: 81 to sum, multiplier: 27
// Adding number: 84 to sum, multiplier: 28
// Adding number: 87 to sum, multiplier: 29
// Adding number: 93 to sum, multiplier: 31
// Adding number: 96 to sum, multiplier: 32
// Adding number: 99 to sum, multiplier: 33
// Adding number: 102 to sum, multiplier: 34
// Adding number: 108 to sum, multiplier: 36
// Adding number: 111 to sum, multiplier: 37
// Adding number: 114 to sum, multiplier: 38
// Adding number: 117 to sum, multiplier: 39
// Adding number: 123 to sum, multiplier: 41
// Adding number: 126 to sum, multiplier: 42
// Adding number: 129 to sum, multiplier: 43
// Adding number: 132 to sum, multiplier: 44
// Adding number: 138 to sum, multiplier: 46
// Adding number: 141 to sum, multiplier: 47
// Adding number: 144 to sum, multiplier: 48
// Adding number: 147 to sum, multiplier: 49
// Adding number: 153 to sum, multiplier: 51
// Adding number: 156 to sum, multiplier: 52
// Adding number: 159 to sum, multiplier: 53
// Adding number: 162 to sum, multiplier: 54
// Adding number: 168 to sum, multiplier: 56
// Adding number: 171 to sum, multiplier: 57
// Adding number: 174 to sum, multiplier: 58
// Adding number: 177 to sum, multiplier: 59
// Adding number: 183 to sum, multiplier: 61
// Adding number: 186 to sum, multiplier: 62
// Adding number: 189 to sum, multiplier: 63
// Adding number: 192 to sum, multiplier: 64
// Adding number: 198 to sum, multiplier: 66
// Adding number: 201 to sum, multiplier: 67
// Adding number: 204 to sum, multiplier: 68
// Adding number: 207 to sum, multiplier: 69
// Adding number: 213 to sum, multiplier: 71
// Adding number: 216 to sum, multiplier: 72
// Adding number: 219 to sum, multiplier: 73
// Adding number: 222 to sum, multiplier: 74
// Adding number: 228 to sum, multiplier: 76
// Adding number: 231 to sum, multiplier: 77
// Adding number: 234 to sum, multiplier: 78
// Adding number: 237 to sum, multiplier: 79
// Adding number: 243 to sum, multiplier: 81
// Adding number: 246 to sum, multiplier: 82
// Adding number: 249 to sum, multiplier: 83
// Adding number: 252 to sum, multiplier: 84
// Adding number: 258 to sum, multiplier: 86
// Adding number: 261 to sum, multiplier: 87
// Adding number: 264 to sum, multiplier: 88
// Adding number: 267 to sum, multiplier: 89
// Adding number: 273 to sum, multiplier: 91
// Adding number: 276 to sum, multiplier: 92
// Adding number: 279 to sum, multiplier: 93
// Adding number: 282 to sum, multiplier: 94
// Adding number: 288 to sum, multiplier: 96
// Adding number: 291 to sum, multiplier: 97
// Adding number: 294 to sum, multiplier: 98
// Adding number: 297 to sum, multiplier: 99
// Adding number: 303 to sum, multiplier: 101
// Adding number: 306 to sum, multiplier: 102
// Adding number: 309 to sum, multiplier: 103
// Adding number: 312 to sum, multiplier: 104
// Adding number: 318 to sum, multiplier: 106
// Adding number: 321 to sum, multiplier: 107
// Adding number: 324 to sum, multiplier: 108
// Adding number: 327 to sum, multiplier: 109
// Adding number: 333 to sum, multiplier: 111
// Adding number: 336 to sum, multiplier: 112
// Adding number: 339 to sum, multiplier: 113
// Adding number: 342 to sum, multiplier: 114
// Adding number: 348 to sum, multiplier: 116
// Adding number: 351 to sum, multiplier: 117
// Adding number: 354 to sum, multiplier: 118
// Adding number: 357 to sum, multiplier: 119
// Adding number: 363 to sum, multiplier: 121
// Adding number: 366 to sum, multiplier: 122
// Adding number: 369 to sum, multiplier: 123
// Adding number: 372 to sum, multiplier: 124
// Adding number: 378 to sum, multiplier: 126
// Adding number: 381 to sum, multiplier: 127
// Adding number: 384 to sum, multiplier: 128
// Adding number: 387 to sum, multiplier: 129
// Adding number: 393 to sum, multiplier: 131
// Adding number: 396 to sum, multiplier: 132
// Adding number: 399 to sum, multiplier: 133
// Adding number: 402 to sum, multiplier: 134
// Adding number: 408 to sum, multiplier: 136
// Adding number: 411 to sum, multiplier: 137
// Adding number: 414 to sum, multiplier: 138
// Adding number: 417 to sum, multiplier: 139
// Adding number: 423 to sum, multiplier: 141
// Adding number: 426 to sum, multiplier: 142
// Adding number: 429 to sum, multiplier: 143
// Adding number: 432 to sum, multiplier: 144
// Adding number: 438 to sum, multiplier: 146
// Adding number: 441 to sum, multiplier: 147
// Adding number: 444 to sum, multiplier: 148
// Adding number: 447 to sum, multiplier: 149
// Adding number: 453 to sum, multiplier: 151
// Adding number: 456 to sum, multiplier: 152
// Adding number: 459 to sum, multiplier: 153
// Adding number: 462 to sum, multiplier: 154
// Adding number: 468 to sum, multiplier: 156
// Adding number: 471 to sum, multiplier: 157
// Adding number: 474 to sum, multiplier: 158
// Adding number: 477 to sum, multiplier: 159
// Adding number: 483 to sum, multiplier: 161
// Adding number: 486 to sum, multiplier: 162
// Adding number: 489 to sum, multiplier: 163
// Adding number: 492 to sum, multiplier: 164
// Adding number: 498 to sum, multiplier: 166
// Adding number: 501 to sum, multiplier: 167
// Adding number: 504 to sum, multiplier: 168
// Adding number: 507 to sum, multiplier: 169
// Adding number: 513 to sum, multiplier: 171
// Adding number: 516 to sum, multiplier: 172
// Adding number: 519 to sum, multiplier: 173
// Adding number: 522 to sum, multiplier: 174
// Adding number: 528 to sum, multiplier: 176
// Adding number: 531 to sum, multiplier: 177
// Adding number: 534 to sum, multiplier: 178
// Adding number: 537 to sum, multiplier: 179
// Adding number: 543 to sum, multiplier: 181
// Adding number: 546 to sum, multiplier: 182
// Adding number: 549 to sum, multiplier: 183
// Adding number: 552 to sum, multiplier: 184
// Adding number: 558 to sum, multiplier: 186
// Adding number: 561 to sum, multiplier: 187
// Adding number: 564 to sum, multiplier: 188
// Adding number: 567 to sum, multiplier: 189
// Adding number: 573 to sum, multiplier: 191
// Adding number: 576 to sum, multiplier: 192
// Adding number: 579 to sum, multiplier: 193
// Adding number: 582 to sum, multiplier: 194
// Adding number: 588 to sum, multiplier: 196
// Adding number: 591 to sum, multiplier: 197
// Adding number: 594 to sum, multiplier: 198
// Adding number: 597 to sum, multiplier: 199
// Adding number: 603 to sum, multiplier: 201
// Adding number: 606 to sum, multiplier: 202
// Adding number: 609 to sum, multiplier: 203
// Adding number: 612 to sum, multiplier: 204
// Adding number: 618 to sum, multiplier: 206
// Adding number: 621 to sum, multiplier: 207
// Adding number: 624 to sum, multiplier: 208
// Adding number: 627 to sum, multiplier: 209
// Adding number: 633 to sum, multiplier: 211
// Adding number: 636 to sum, multiplier: 212
// Adding number: 639 to sum, multiplier: 213
// Adding number: 642 to sum, multiplier: 214
// Adding number: 648 to sum, multiplier: 216
// Adding number: 651 to sum, multiplier: 217
// Adding number: 654 to sum, multiplier: 218
// Adding number: 657 to sum, multiplier: 219
// Adding number: 663 to sum, multiplier: 221
// Adding number: 666 to sum, multiplier: 222
// Adding number: 669 to sum, multiplier: 223
// Adding number: 672 to sum, multiplier: 224
// Adding number: 678 to sum, multiplier: 226
// Adding number: 681 to sum, multiplier: 227
// Adding number: 684 to sum, multiplier: 228
// Adding number: 687 to sum, multiplier: 229
// Adding number: 693 to sum, multiplier: 231
// Adding number: 696 to sum, multiplier: 232
// Adding number: 699 to sum, multiplier: 233
// Adding number: 702 to sum, multiplier: 234
// Adding number: 708 to sum, multiplier: 236
// Adding number: 711 to sum, multiplier: 237
// Adding number: 714 to sum, multiplier: 238
// Adding number: 717 to sum, multiplier: 239
// Adding number: 723 to sum, multiplier: 241
// Adding number: 726 to sum, multiplier: 242
// Adding number: 729 to sum, multiplier: 243
// Adding number: 732 to sum, multiplier: 244
// Adding number: 738 to sum, multiplier: 246
// Adding number: 741 to sum, multiplier: 247
// Adding number: 744 to sum, multiplier: 248
// Adding number: 747 to sum, multiplier: 249
// Adding number: 753 to sum, multiplier: 251
// Adding number: 756 to sum, multiplier: 252
// Adding number: 759 to sum, multiplier: 253
// Adding number: 762 to sum, multiplier: 254
// Adding number: 768 to sum, multiplier: 256
// Adding number: 771 to sum, multiplier: 257
// Adding number: 774 to sum, multiplier: 258
// Adding number: 777 to sum, multiplier: 259
// Adding number: 783 to sum, multiplier: 261
// Adding number: 786 to sum, multiplier: 262
// Adding number: 789 to sum, multiplier: 263
// Adding number: 792 to sum, multiplier: 264
// Adding number: 798 to sum, multiplier: 266
// Adding number: 801 to sum, multiplier: 267
// Adding number: 804 to sum, multiplier: 268
// Adding number: 807 to sum, multiplier: 269
// Adding number: 813 to sum, multiplier: 271
// Adding number: 816 to sum, multiplier: 272
// Adding number: 819 to sum, multiplier: 273
// Adding number: 822 to sum, multiplier: 274
// Adding number: 828 to sum, multiplier: 276
// Adding number: 831 to sum, multiplier: 277
// Adding number: 834 to sum, multiplier: 278
// Adding number: 837 to sum, multiplier: 279
// Adding number: 843 to sum, multiplier: 281
// Adding number: 846 to sum, multiplier: 282
// Adding number: 849 to sum, multiplier: 283
// Adding number: 852 to sum, multiplier: 284
// Adding number: 858 to sum, multiplier: 286
// Adding number: 861 to sum, multiplier: 287
// Adding number: 864 to sum, multiplier: 288
// Adding number: 867 to sum, multiplier: 289
// Adding number: 873 to sum, multiplier: 291
// Adding number: 876 to sum, multiplier: 292
// Adding number: 879 to sum, multiplier: 293
// Adding number: 882 to sum, multiplier: 294
// Adding number: 888 to sum, multiplier: 296
// Adding number: 891 to sum, multiplier: 297
// Adding number: 894 to sum, multiplier: 298
// Adding number: 897 to sum, multiplier: 299
// Adding number: 903 to sum, multiplier: 301
// Adding number: 906 to sum, multiplier: 302
// Adding number: 909 to sum, multiplier: 303
// Adding number: 912 to sum, multiplier: 304
// Adding number: 918 to sum, multiplier: 306
// Adding number: 921 to sum, multiplier: 307
// Adding number: 924 to sum, multiplier: 308
// Adding number: 927 to sum, multiplier: 309
// Adding number: 933 to sum, multiplier: 311
// Adding number: 936 to sum, multiplier: 312
// Adding number: 939 to sum, multiplier: 313
// Adding number: 942 to sum, multiplier: 314
// Adding number: 948 to sum, multiplier: 316
// Adding number: 951 to sum, multiplier: 317
// Adding number: 954 to sum, multiplier: 318
// Adding number: 957 to sum, multiplier: 319
// Adding number: 963 to sum, multiplier: 321
// Adding number: 966 to sum, multiplier: 322
// Adding number: 969 to sum, multiplier: 323
// Adding number: 972 to sum, multiplier: 324
// Adding number: 978 to sum, multiplier: 326
// Adding number: 981 to sum, multiplier: 327
// Adding number: 984 to sum, multiplier: 328
// Adding number: 987 to sum, multiplier: 329
// Adding number: 993 to sum, multiplier: 331
// Adding number: 996 to sum, multiplier: 332
// Adding number: 999 to sum, multiplier: 333
// 233168

// %% [markdown]
// Still, this approach still just linear
// the first loop goes from i = 1 to (max-1) / 5 (max / 5 iterations)
// the second loop goes from i = 1 to (max-1) / 3 (max / 3 iterations)
// total iterations = max/5 + max/3 = 8max/15
// so this approach does reduce total numbers to 8/15 of the set, but the growth of the approach is linear
// since if I doubled the set (calling the function for 2000) the iterations would doubled also.

// %% [markdown]
// ## Actually optimized solution
// So in this case I found out the solution using the sum of the sequence in algebra (It's a mistake of me not considering this formula but only using a programmatic way). First I should understand what I'm doing.
//
// ### Arithmetic progression (A.K.A arithmetic sequence, linear sequence)
// Basically it is a chain of numbers (sequence of numbers) that any preceding term and succeeding term pair have the same difference.
// Suppose I have a sequence of numbers: 2, 4, 6, 8, 10, 12
// This is the the arithmetic progression because any succeeding number have the same difference to the number before it: 4-2 = 2, 6-4 = 2. 2 is called a common difference and is a constant.
//
// ## Sum of an arithmetic progression
// $S=\frac{n(a_1+a_n)}{2}$
//
// for $a_1$ is the first element and $a_n$ is the last element of the sequence of size n
//
// ## Solving the problem
// So in the problem, finding multiples of 3 is the same as finding every number starting from 3 and add 3 for each step:
// $S(3)={3, 6, 9, 12, 15, 18,...}$
//
// Then I have the length of the sequence, which is a number less than 1000 and is divisible by 3
// I can reduce the largest number by 1 and perform a check if it is divisible by 3, it woudl take less than or equal 3 steps for the result
// Now I can use the formula to calculate the sum
// I can do the same for 5 and it would take less than 6 steps for that also
// Then I sum the 2 result with each other and it will be the ouput.
// Wrong.
// ## Duplication
// Since I sum the set of 3 and the set of 5 multiples, that would include the set of numbers that are both divisible by 3 and by 5, which then we will duplicate the set we have.
//
// For example, after the sum I now have 1 $S(3)$, 1 $S(5)$, and 2 $S(3) \cap S(5)$
//
// But we want to have a set of number divisible by 3, one by 5 and one both by 3 and 5. So we subtract one $S(3) \cap S(5)$ out
// $$S = S(3) + S(5) - S(3) \cap S(5)$$
// Then we have an output, much optimized

// %%
fun sequenceSum(start: Int, end: Int, step: Int): Int {
    return ((end / step)*(start + end)) / 2
}

fun floorMultiple(n: Int, multiplier: Int) = (n / multiplier) * multiplier
fun multipleSumOptimized(max: Int): Int {
    val k = max - 1
    return sequenceSum(3, floorMultiple(k, 3), 3) + sequenceSum(5, floorMultiple(k, 5), 5) - sequenceSum(15, floorMultiple(k, 15), 15)
}

// %%
multipleSumOptimized(1000)
// Out:
// 233168
